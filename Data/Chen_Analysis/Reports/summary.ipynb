# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../Data/Chen_Analysis/summary.tsv", sep="\t")
df.head()
# Out:
#              file format type  num_seqs  sum_len  min_len  avg_len  max_len  \
# 0  GOMC.bin.10027  FASTA  DNA       590  5007018     1500   8486.5    79977
# 1  GOMC.bin.10037  FASTA  DNA       881  6342371     1501   7199.1    51156
# 2  GOMC.bin.10082  FASTA  DNA       495  3581699     1506   7235.8    39465
# 3  GOMC.bin.10102  FASTA  DNA       151  4160111     1520  27550.4   386529
# 4  GOMC.bin.10144  FASTA  DNA       519  3872192     1500   7460.9    42010
#
#      Q1     Q2     Q3  sum_gap    N50  N50_num  Q20(%)  Q30(%)  AvgQual  \
# 0  2431   4684  10820        0  15272       98       0       0      0.0
# 1  3033   5081   9242        0  10127      193       0       0      0.0
# 2  2692   5238   9700        0  10560      107       0       0      0.0
# 3  2336  10192  35888        0  65890       18       0       0      0.0
# 4  2847   4944   9893        0  11625      104       0       0      0.0
#
#    GC(%)  sum_n
# 0  65.97      0
# 1  46.56      0
# 2  40.17      0
# 3  30.90      0
# 4  67.14      0

# %%
cols = ["num_seqs", "sum_len", "max_len", "N50"]

plt.figure(figsize=(6,4))
for i, col in enumerate(cols, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df[col], kde=True)
    plt.title(col)

plt.tight_layout()
plt.savefig("../../Data/Chen_Analysis/Reports/dist.png")

# %%
pd.set_option('display.float_format', '{:.0f}'.format)

for col in cols:
    print(df[col].describe())
# Out:
# count    473
# mean     354
# std      236
# min        4
# 25%      161
# 50%      299
# 75%      516
# max     1034
# Name: num_seqs, dtype: float64
# count        473
# mean     2518983
# std      1436686
# min       351229
# 25%      1546122
# 50%      2259700
# 75%      3177760
# max     11042267
# Name: sum_len, dtype: float64
# count       473
# mean      83703
# std      141920
# min        6968
# 25%       21817
# 50%       38626
# 75%       87569
# max     1757649
# Name: max_len, dtype: float64
# count       473
# mean      28636
# std       93721
# min        1840
# 25%        4916
# 50%        9072
# 75%       22685
# max     1757649
# Name: N50, dtype: float64

# %%
plt.figure(figsize=(6, 4))
for i, col in enumerate(cols, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(y=df[col])
    plt.yscale('log')
    plt.title(col)

plt.tight_layout()
plt.savefig("../../Data/Chen_Analysis/Reports/boxplot.png")

# %%
num_seq = df["num_seqs"]

q1 = num_seq.quantile(0.25)
q3 = num_seq.quantile(0.75)
iqr = q3 - q1
supl = q3 + 1.5 * iqr

df_iqr = df[num_seq <= supl]
df_iqr["num_seqs"].describe()
# Out:
# count    473
# mean     354
# std      236
# min        4
# 25%      161
# 50%      299
# 75%      516
# max     1034
# Name: num_seqs, dtype: float64

# %%
df_iqr.to_csv('../../Data/Chen_Analysis/summary_iqr.csv', index=False)
